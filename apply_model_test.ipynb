# %%
# always reload an imported module before executing a particular cell
# (used to let changes in python files take effect without restarting kernel)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sentence_transformers import SentenceTransformer, LoggingHandler
import numpy as np
import os
import pandas as pd
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.corpus import stopwords

# %%
queries_file= '/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/queries3.csv'

df = pd.read_csv(queries_file, error_bad_lines=False)

df.head(3)
# Out:
#    qid                            query  rel      type  \
# 0    0  aaa a common cause of a skid is    0  original
# 1    0  aaa a common cause of a skid is    0  original
# 2    0  aaa a common cause of a skid is    0  original
#
#                                                  doc
# 0  Discounts and benefits are available at all He...
# 1  AAA North Penn provides Authorized On - Line P...
# 2  â¢ EAP-TLS authentication takes place between...

# %%
from abc import ABC, abstractmethod

class Ranker(ABC):
    
    @abstractmethod
    def rank(self, query, docs):
        """
        Return sorted indices
        """
        pass
    
    @staticmethod
    def sims_to_indices(sims):
        indexed_sims = enumerate(sims.squeeze())   
        indexed_sims_sorted = sorted(indexed_sims, key=lambda x:x[1], reverse=False)
        indices_sorted = [x[0] for x in indexed_sims_sorted]
        return indices_sorted

# %%
from scipy.spatial.distance import cdist
from sklearn.metrics.pairwise import cosine_similarity

class SBERTRanker(Ranker):
    def __init__(self, model):
        self.model = model
        
    def rank(self, query, docs):
        embeddings = model.encode([query] + docs)

        sims = cdist(embeddings[0].reshape(-1,1).T, embeddings[1:], "cosine")[0]
        indices_sorted = self.sims_to_indices(sims)
        
        return indices_sorted

# %%
model = SentenceTransformer('roberta-large-nli-stsb-mean-tokens')

# %%
sbert_ranker = SBERTRanker(model)

# %%
sbert_ranker.rank('i saw a cat', ['the cat was seen by me', 'pineapple on pizza is bad', 'i saw a cat'])
# Out:
# [2, 0, 1]

# %%
class Doc2vecRanker(Ranker):
    
    stopwords = set(stopwords.words('english'))
    
    def __init__(self, model_fn):
        self.model = Doc2Vec.load(model_fn)        
    
    def _preprocess_text(self, text):
        words = nltk.word_tokenize(text)
        words = [word.lower() for word in words if word.isalpha()]
        words = [w for w in words if not w in self.stopwords]
        return words
    
    def rank(self, query, docs):
        query_vector = self.model.infer_vector(self._preprocess_text(query))
        doc_vectors = [self.model.infer_vector(self._preprocess_text(d)) for d in docs]
        
        sims = cdist(query_vector.reshape(-1,1).T, np.array(doc_vectors), "cosine")[0]
        
        print(sims)
        indices_sorted = self.sims_to_indices(sims)
        
        return indices_sorted

# %%
d2v_ranker = Doc2vecRanker('/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/train_results/doc2vec2/d2v_2')

# %%
d2v_ranker.rank('i saw a cat', ['the cat was seen by me', 'cat cat cat', 'i saw a cat'])
# Out:
# [1.02262315 0.9711936  0.        ]
# [2, 1, 0]

# %%
"""
# Compute the normalized LCS given an answer text and a source text
def lcs_norm_word(answer_text, source_text):
    '''Computes the longest common subsequence of words in two texts; returns a normalized value.
       :param answer_text: The pre-processed text for an answer text
       :param source_text: The pre-processed text for an answer's associated source text
       :return: A normalized LCS value'''
    
    answer_text = answer_text.split()
    source_text = source_text.split()
    
    m = np.zeros((len(answer_text)+1, len(source_text)+1))

    for i in range(1, len(source_text)+1):
        for j in range(1, len(answer_text)+1):
            if source_text[i-1] == answer_text[j-1]:
                m[j,i] = m[j-1,i-1] +1
            else:
                m[j,i] = max(m[j-1,i], m[j,i-1])
    return m[len(answer_text),len(source_text)] / len(answer_text)

"""

# %%
def calc_rr(rels_sorted, types_sorted, ttype='original', rel_label=1):
    indices = np.where(rels_sorted == rel_label)[0]
    #print(indices)
    original = np.where(types_sorted[indices] == ttype)[0]
    if len(original) == 0:
        raise Exception('no relevant docs of this type')
    return np.mean(1 / (indices[original]+1))

# %%
def calculate_mrr_stats(ranker,
                        types=['original', 'degree_2', 'degree_3', 'degree_4', 
                               'degree_4_split', 'degree_8', 'degree_8_split'],
                        limit=None
                       ):

    rr_df = pd.DataFrame(columns=['qid'] + types + ['original_irrelevant'])

    qids = list(set(df['qid']))
    nr_qids = len(qids)
    for i, qid in enumerate(qids):
        
        if limit is not None and i >= limit:
            break
            
        query_df = df[df['qid'] == qid].reset_index(drop=True)
        query = query_df['query'].iloc[0]
        print('query:', query)

        indices_sorted = ranker.rank(query, query_df['doc'].values.tolist())   

        docs_sorted = query_df.iloc[indices_sorted]

        query_rr_row = [qid]
        for ttype in types:
            query_rr_row.append(calc_rr(docs_sorted['rel'].values, docs_sorted['type'].values, ttype=ttype))
        query_rr_row.append(calc_rr(docs_sorted['rel'].values, 
                                    docs_sorted['type'].values, ttype='original', 
                                    rel_label=0))        
        rr_df = rr_df.append(pd.Series(query_rr_row, index=rr_df.columns), ignore_index=True)

        if (i+1) % 5 ==  0:
            print('processed {:d} of {:d}'.format(i+1, nr_qids))
        
    
    return rr_df

# %%
ranker = SBERTRanker(model)

rr_df = calculate_mrr_stats(ranker, limit=400)
# Out:
# query: aaa a common cause of a skid is
# query: chionophobia is an abnormal fear of what
# query: abcmouse price
# query: abnormal condition of blood in a joint
# query: about how long can a bald eagle live?
# processed 5 of 20117
# query: 1 cup of strawberries nutrition facts
# query: sprint pay by phone telephone number
# query: is lameness a type of abnormal locomotion
# query: what is pica condition
# query: . in what kind of government does a small group have a firm control over a country? brainly
# processed 10 of 20117
# query: aaa templin phone number
# query: according to the amdr what percentage of your daily intake should be protein
# query: how to care for goji berry plants
# query: how to become a firefighter in pa
# query: how costly is it to remove mold from crawl space
# processed 15 of 20117
# query: do raccoons eat japanese beetles
# query: what is a raccoon dog
# query: how to calculate growth of dividend
# query: how to cancel your zipcar membership
# query: what helps get rid of moisture in basement
# processed 20 of 20117
# query: what are marshmallows made of
# query: how to catch a raccoon
# query: accrued expense define accrued expense
# query: disease that affect raccoons
# query: how was the raccoon introduced to germany
# processed 25 of 20117
# query: president who had a raccoon named rebecca
# query: how to buy a mcdonald's franchise cost
# query: acer computer customer service number
# query: accounts receivable vs accounts payable
# query: what is the yearly salary of a critical care rn
# processed 30 of 20117
# query: how to change credit card limit uob
# query: how to check my booking on saudi airlines
# query: what is thromboembolism prophylaxis
# query: what is the world's fastest train
# query: what is the world ungulates mean
# processed 35 of 20117
# query: how to check prevailing wage status
# query: what is the world record for knowing digits of pi
# query: what is the zip code for sebring florida
# query: what is tool cavitation
# query: what is touch rugby
# processed 40 of 20117
# query: alexa lf
# query: akron children's hospital number
# query: what is trajectory mean
# query: what is tow mode
# query: what is traditional economy
# processed 45 of 20117
# query: albany empire afl team
# query: alex rider operation stormbreaker cast
# query: amnesty define
# query: ally auto number
# query: allergan us headquarters address
# processed 50 of 20117
# query: american cheese calories slice
# query: amniocentesis is performed what trimester
# query: amendments that address voting rights
# query: amount of money for college graduation gift
# query: amazon seattle office phone number
# processed 55 of 20117
# query: amnesty definition
# query: are halal marshmallow gelatin
# query: amsterdam citizens are called what
# query: average cost of wedding dinner per person park savoy
# query: at what age can a child leave home legally to live with another parent
# processed 60 of 20117
# query: are sunpatiens annuals or perennials
# query: an account # has how many numbers including zeros
# query: average cost of cataract surgery without insurance
# query: average amount food stamps per one person in al for a month
# query: addison's disease in dogs symptoms
# processed 65 of 20117
# query: adt pulse camera price
# query: advocacy organisation definition
# query: age divisions soccer
# query: adhesion molecules definition
# query: average income rome italy
# processed 70 of 20117
# query: agency definition government
# query: add homonym definition
# query: admiral customer service phone number
# query: age limit for roth ira deduction
# query: age requirements for fishing license in ny state
# processed 75 of 20117
# query: age of dependents on tax return
# query: age of dolly parton
# query: aides or aids definition
# query: agile computing
# query: age to enter into legal contract
# processed 80 of 20117
# query: age rules for florida fishing license
# query: age requirement for traditional ira
# query: sigmund freud is the creator/founder of _______.
# query: why do we repress freud
# query: how much do psychologists make hourly
# processed 85 of 20117
# query: another name for puerto rican
# query: another name for royalty
# query: amtrak phone numbers
# query: anaesthetic definition
# query: anemia and colon cancer symptoms
# processed 90 of 20117
# query: what does a Clinical Neuropsychologist do
# query: annual average rainfall in australian capital cities
# query: annual defined contribution limit mean
# query: what does annual defined contribution limit mean
# query: annual cost tankless water heater
# processed 95 of 20117
# query: apoplexy define
# query: another term for revenue
# query: aol customer service telephone number
# query: another term for sty is
# query: an electron group is defined as
# processed 100 of 20117
# query: anytime fitness franchise list
# query: apple remote desktop
# query: anytime fitness rowville
# query: apathetic audience definition
# query: are cnn ratings falling
# processed 105 of 20117
# query: are heritage chicken good meat
# query: are gas or electric dryers more efficient
# query: are any sears store closing in columbus ohio
# query: are irs debts forgiven
# query: app to open zip files
# processed 110 of 20117
# query: are figs considered tree nuts
# query: are dumbbell squats effective
# query: are employee contributions to a defined benefit plan pre-tax or after-tax
# query: are hermit crabs reptiles
# query: are platypuses deadly
# processed 115 of 20117
# query: are supplements necessary for athletes
# query: are nursing attendant positions paid at ny presbyterian
# query: are limes a natural diuretic
# query: are plums good for constipation
# query: are papillons hypoallergenic
# processed 120 of 20117
# query: are petunias perennials
# query: are most favored nation clauses legal
# query: are nike air max durable
# query: asos.com international number
# query: asthma symptoms when sleeping
# processed 125 of 20117
# query: ashland is in what county?
# query: asbestos removal should i remove
# query: are tree names capitalized
# query: are the alkali metals reactive
# query: are toucans warm blooded
# processed 130 of 20117
# query: associate scientist salary
# query: are treasury notes marketable
# query: arsenal is a soccer team?
# query: at what age do people normally develop presbyopia
# query: astoria or is in what county
# processed 135 of 20117
# query: attire definition
# query: at what age does child support end in massachusetts
# query: atacama desert chile weather
# query: cocktail attire definition
# query: at&t wireless phone number customer service
# processed 140 of 20117
# query: at what age do you get your wisdom teeth out
# query: at what age should i get the shingles vaccine
# query: at what age do you get the chickenpox vaccine
# query: dress attire definition
# query: austin texas  is in what county
# processed 145 of 20117
# query: average annual temperature of Uruguay
# query: average annual temperature indianapolis
# query: average training hours global
# query: how long is an average pregnancy
# query: average annual global temperature
# processed 150 of 20117
# query: average age of statesville residents
# query: average annual temperature cary nc
# query: at what speed does a tropical storm reach hurricane strength
# query: how long is the average head
# query: at what temperature can you see your breath
# processed 155 of 20117
# query: average axial length of eye
# query: avelox uses dosage side effects
# query: average baby weight by month
# query: average born baby weight
# query: average college student age
# processed 160 of 20117
# query: average cost of diapers for baby's first year
# query: average cost of colorbond fencing per metre
# query: average bartender salary wa
# query: average college student allowance per week
# query: average cost of a brake job
# processed 165 of 20117
# query: average cost for termite treatment for business
# query: average cost of linoleum flooring
# query: average cost of shoulder replacement surgery
# query: average cost of fence homeadvisor
# query: average cost of graduate school
# processed 170 of 20117
# query: average cost of full upper denture
# query: average cost of heat pump and furnace with installation
# query: average cost of home insurance for flood zone area in ct
# query: average cost of toe shortening surgery uk
# query: average cost of dog hernia surgery
# processed 175 of 20117
# query: average cost of groceries for college student
# query: average monthly costs to treat diabetes
# query: how mych does golds gym membership cost in el paso?
# query: krewe of femme fatale membership cost
# query: what qualifications do a gym general manager needs
# processed 180 of 20117
# query: gold gym membership cost
# query: how much is a anytime fitness membership
# query: monthly cost of a horse
# query: adt average monthly cost
# query: which cost is an example of a variable cost?
# processed 185 of 20117
# query: cost of planet fitness membership
# query: what's the cost of a costco executive membership
# query: average entertainment cost per month
# query: monthly cost of avastin cancer treatment
# query: monthly t1 line cost
# processed 190 of 20117
# query: what are david barton gyms
# query: usga basic membership cost
# query: monthly cost for hulu
# query: types of membership models
# query: orange theory fitness membership cost
# processed 195 of 20117
# query: how much is membership at a fitness club
# query: average human stomach size
# query: how much do gold's gym employees make
# query: how much is a kickboxing membership
# query: fold3 membership cost
# processed 200 of 20117
# query: cost of membership at river landing
# query: how much do gym mirrors cost
# query: what percentage of people get pregnant within the first month of trying
# query: nerc membership costs
# query: how much does it cost to belong to a country club
# processed 205 of 20117
# query: koa membership cost
# query: cost of title boxing membership
# query: cost of nln membership
# query: what is the cost of aaa plus membership
# query: how much is shipt membership
# processed 210 of 20117
# query: basic membership usga cost
# query: what the costco membership cost
# query: how much does runescape membership cost
# query: average dose of latuda for bipolar
# query: average amount of money needed for groceries a month
# processed 215 of 20117
# query: cost of anytime fitness membership fees
# query: average amount of money spent on cigarettes per year
# query: what is the cost of pogo club membership
# query: average yearly cost for mcc
# query: average daily membership
# processed 220 of 20117
# query: lvac membership cost
# query: monthly cost of raising a child
# query: what does a fitness connection membership cost
# query: how do you cancel gold's gym membership
# query: basic aaa membership cost
# processed 225 of 20117
# query: average income clinical psychologist
# query: what does a membership in match cost
# query: pure gym franchise cost
# query: apa membership cost
# query: what is the cost of membership at costco
# processed 230 of 20117
# query: curves cost of membership
# query: average gym membership cost
# query: how old can you be to get a gym membership
# query: average income for car washers
# query: what is lifetime fitness
# processed 235 of 20117
# query: what machines should i use at the gym for abs
# query: how much is seabrook island club membership
# query: cost of amsa membership
# query: how much is planet fitness initiation fee
# query: how much ntuc membership fee
# processed 240 of 20117
# query: how much does total gym cost
# query: cost to open a gym
# query: nyc equinox membership cost
# query: what is the average weight of a one year old boy
# query: average baby weight by month
# processed 245 of 20117
# query: how much does it cost to have a personal trainer at gold gym
# query: denny price ymca memberships
# query: aep average monthly cost
# query: monthly cost of living in georgia
# query: average cost of gym membership per month
# processed 250 of 20117
# query: cost of christian mingle membership
# query: monthly cost of avastin
# query: cost of equinox membership
# query: what is sam's club membership
# query: how much does it cost to have a membership at augusta national
# processed 255 of 20117
# query: how much does prime cost monthly
# query: anytime fitness cost of membership
# query: average healthy heart rate bpm women
# query: how much does a aaa membership cost?
# query: bjj monthly cost
# processed 260 of 20117
# query: average cost of tanning membership
# query: annual cost of disney vacation club membership
# query: cost of prime membership by the month
# query: average debt for college graduates
# query: what is the monthly fee for ymca membership
# processed 265 of 20117
# query: how much does it cost for a sam's membership
# query: cost to open up a new gym equipment
# query: what does a membership cost at Anytime fitness
# query: average feet per stride
# query: amazon prime membership cost per month
# processed 270 of 20117
# query: how much is anytime fitness membership
# query: usa swimming membership cost
# query: average fee to set up smsf
# query: average hybrid battery life
# query: average weight eleven month old boy
# processed 275 of 20117
# query: anytime fitness monthly membership cost
# query: match.com cost of membership
# query: average general contractor fee percentage
# query: how much does a gym membership cost
# query: mcc membership cost
# processed 280 of 20117
# query: average cost of a golf membership
# query: cost of audible gold membership
# query: cost of hog membership
# query: cost for anytime fitness membership
# query: average morning sugar count
# processed 285 of 20117
# query: what is a medical transcriptionist hourly pay
# query: highest mts in arizona
# query: average length of bobtail
# query: how much does it cost for medical transcription training
# query: average salary for medical transcriptionist
# processed 290 of 20117
# query: what is lvad in medical terms?
# query: how much does an average medical transcription make
# query: do you have to take a course to be a general transcriptionist
# query: average income in utah per person
# query: average life of heat pump compressor
# processed 295 of 20117
# query: where are the catalina mts in az.
# query: average rate of pay transcriptionist
# query: how much can a transcriptionist make
# query: average life usage water heater
# query: what is afe medical
# processed 300 of 20117
# query: do you treat productive coughs
# query: average pay for system support specialist
# query: average installation price for carpet
# query: average medical transcriptionist salary
# query: what is a medical avn
# processed 305 of 20117
# query: average income in hawaii
# query: how much does a medical transcriptionist make in australia
# query: what is cytokine production for
# query: average miles per year on vehicle
# query: average price of vinyl fence installed
# processed 310 of 20117
# query: average retirement age for police officers
# query: average per square foot price for copmmercial construction
# query: average perrysburg home square feet
# query: average recovery time from total hip replacement
# query: average price for granite per square foot
# processed 315 of 20117
# query: average petrol price melbourne 2015
# query: average price per square foot of industrial property in fort smith arkansas
# query: average revenue is equal to
# query: definition of a scalar
# query: payscale salary for registered client service associate
# processed 320 of 20117
# query: average reading speed
# query: how much does a psychologist doctor make a year
# query: which measurement is a vector quantity
# query: what is the average starting salary for a college graduate
# query: average thickness of a cabinet door
# processed 325 of 20117
# query: average salary for a rn in ohio
# query: what is the base salary for a recruiter
# query: average salaries amazon
# query: what does a criminal psychologist do
# query: average adult typing speed
# processed 330 of 20117
# query: salary and education for school psychologist
# query: rate of pay school psychologist
# query: how much does a psychologist make
# query: average salary for clinical psychologist
# query: how many hours does a psychologist do
# processed 335 of 20117
# query: average salary gamestop
# query: average hiking speed
# query: average wage for a clinical pharmacologist
# query: Average speed is defined as
# query: can a landscape architect's salary increase annually
# processed 340 of 20117
# query: define engine displacement
# query: how much does a psychologist make in the military
# query: average architect starting salary
# query: average rn salary in memphis
# query: average temperature during winter in lake superior
# processed 345 of 20117
# query: average sport psychologist salary
# query: difference between a psychologist psychiatrist
# query: average clinical educator for philips monitors
# query: aacn average starting salary of rns
# query: symptoms of iud displacement
# processed 350 of 20117
# query: how to be a child psychologist
# query: average salary human resources recruiter
# query: average salary first year lawyer
# query: what units are used to measure both velocity and speed
# query: average speed on a bike
# processed 355 of 20117
# query: typing speed average
# query: schooling you need to become a child psychologist
# query: if quantity demanded goes down what happens to total revenue
# query: is acceleration considered a vector or scalar
# query: educational psychologist salary
# processed 360 of 20117
# query: average income clinical psychologist
# query: most probable speed formula for gases
# query: what is the average starting salary for an art therapist?
# query: average salary for a school psychologist
# query: average vs instantaneous velocity
# processed 365 of 20117
# query: average salary medical oncology
# query: average salary clinical data coordinator
# query: what is the relationship between displacement and the spring constant k
# query: average hourly rate for philadelphia psychologist
# query: average salary as a psychologist in United States
# processed 370 of 20117
# query: types of clinical psychologist experience
# query: the difference between speed and velocity involves
# query: average tsp balance at retirement
# query: average weight of a bronze turkey
# query: awakening definition
# processed 375 of 20117
# query: second great awakening definition
# query: avis customer service phone number
# query: when does amityville the awakening come out
# query: azithromycin definition
# query: az statute of limitations on defamation
# processed 380 of 20117
# query: azure subscription cost
# query: avora weehawken price
# query: average weight of a newborn baby in kg
# query: average weather in san antonio texas in march
# query: bacteria in the gut affects diabetes
# processed 385 of 20117
# query: dharamsi morarji price
# query: epipen price gouging
# query: upcharge price
# query: vericoin price
# query: price of the homepod
# processed 390 of 20117
# query: a haploid cell has how many chromosomes
# query: what is dictate
# query: ursodiol price
# query: microdermal price
# query: ropinirole price
# processed 395 of 20117
# query: kymriah price
# query: price of xb
# query: the price ceiling that was used to control the price of housing
# query: baja food definition
# query: ibandronate price
# processed 400 of 20117

# %%
rr_df
# Out:
#        qid  original  degree_2  degree_3  degree_4  degree_4_split  degree_8  \
# 0      0.0  0.500000  0.206250  0.136905  0.296259        0.057528  0.040323
# 1      1.0  1.000000  0.213745  0.105420  0.091106        0.148611  0.055914
# 2      2.0  0.071429  0.051042  0.054717  0.078517        0.169338  0.182870
# 3      3.0  1.000000  0.263278  0.064440  0.057346        0.068040  0.148898
# 4      4.0  1.000000  0.200505  0.178030  0.049946        0.114469  0.077782
# ..     ...       ...       ...       ...       ...             ...       ...
# 395  395.0  0.111111  0.110227  0.081496  0.052324        0.047498  0.418779
# 396  396.0  0.083333  0.117469  0.060886  0.429825        0.101190  0.066011
# 397  397.0  1.000000  0.138492  0.189732  0.054852        0.129167  0.046634
# 398  398.0  1.000000  0.134733  0.172393  0.100603        0.056061  0.144037
# 399  399.0  0.250000  0.077621  0.356373  0.166318        0.080603  0.108660
#
#      degree_8_split  original_irrelevant
# 0          0.066947             0.046494
# 1          0.078646             0.039379
# 2          0.085419             0.191220
# 3          0.089815             0.040191
# 4          0.074963             0.038252
# ..              ...                  ...
# 395        0.156481             0.063808
# 396        0.108352             0.058816
# 397        0.136555             0.038384
# 398        0.075956             0.044208
# 399        0.062192             0.053966
#
# [400 rows x 9 columns]

# %%
from datetime import datetime

def get_timestamp():
    now = datetime.now()
    return now.strftime("%Y-%m-%d_%H-%M")

# %%
EVAL_DIR = '/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/eval'

fn = 'rr_queries3_od_model_roberta_400_' + get_timestamp() + '.csv'
rr_df.to_csv(os.path.join(EVAL_DIR, fn), index=None)
