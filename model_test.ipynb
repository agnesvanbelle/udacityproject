# %%
# always reload an imported module before executing a particular cell
# (used to let changes in python files take effect without restarting kernel)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sentence_transformers import SentenceTransformer, LoggingHandler
import numpy as np
import os
import pandas as pd

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
queries_file= '/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/queries.csv'

df = pd.read_csv(queries_file)

df.head(3)
# Out:
#    qid                    query  rel      type  \
# 0    0  are cnn ratings falling    0  original
# 1    0  are cnn ratings falling    0  original
# 2    0  are cnn ratings falling    0  original
#
#                                                  doc
# 0  CNN NewsStand. Not to be confused with routine...
# 1  Using Phone Numbers and Addresses. 1  1. Call ...
# 2  LSMW is the gold standard tool used by functio...

# %%
from abc import ABC, abstractmethod

class Ranker(ABC):
    
    @abstractmethod
    def rank(self, query, docs):
        """
        Return sorted indices
        """
        pass

# %%
from scipy.spatial.distance import cdist
from sklearn.metrics.pairwise import cosine_similarity

class SBERTRanker(Ranker):
    def __init__(self, model):
        self.model = model
        
    def rank(self, query, docs):
        embeddings = model.encode([query] + docs)

        sims = cdist(embeddings[0].reshape(-1,1).T, embeddings[1:], "cosine")[0]
        indexed_sims = enumerate(sims.squeeze())   
        indexed_sims_sorted = sorted(indexed_sims, key=lambda x:x[1], reverse=False)
        indices_sorted = [x[0] for x in indexed_sims_sorted]
        
        return indices_sorted

# %%
def calc_rr(rels_sorted, types_sorted, ttype='original', rel_label=1):
    indices = np.where(rels_sorted == rel_label)[0]
    #print(indices)
    original = np.where(types_sorted[indices] == ttype)[0]
    if len(original) == 0:
        raise Exception('no relevant docs of this type')
    return np.mean(1 / (indices[original]+1))

# %%
def calculate_mrr_stats(ranker,
                        types=['original', 'degree_2', 'degree_3', 'degree_4', 
                               'degree_4_split', 'degree_8', 'degree_8_split'],
                        limit=None
                       ):

    rr_df = pd.DataFrame(columns=['qid'] + types + ['original_irrelevant'])

    qids = list(set(df['qid']))
    nr_qids = len(qids)
    for i, qid in enumerate(qids):
        
        if limit is not None and i >= limit:
            break
            
        query_df = df[df['qid'] == qid].reset_index(drop=True)
        query = query_df['query'].iloc[0]
        print('query:', query)

        indices_sorted = ranker.rank(query, query_df['doc'].values.tolist())   

        docs_sorted = query_df.iloc[indices_sorted]

        query_rr_row = [qid]
        for ttype in types:
            query_rr_row.append(calc_rr(docs_sorted['rel'].values, docs_sorted['type'].values, ttype=ttype))
        query_rr_row.append(calc_rr(docs_sorted['rel'].values, 
                                    docs_sorted['type'].values, ttype='original', 
                                    rel_label=0))        
        rr_df = rr_df.append(pd.Series(query_rr_row, index=rr_df.columns), ignore_index=True)

        if (i+1) % 5 ==  0:
            print('processed {:d} of {:d}'.format(i+1, nr_qids))
        
    
    return rr_df

# %%
ranker = SBERTRanker(model)

rr_df = calculate_mrr_stats(ranker, limit=100)
# Out:
# query: are cnn ratings falling
# query: can polycythemia cause stroke
# query: cancer of the pancreas symptoms
# query: amnesty define
# query: can you have a high magnesium with high calcium
# processed 5 of 86
# query: an electron group is defined as
# query: can you get pregnant day one of your period
# query: can ciprofloxacin be used to treat pneumonia
# query: are most favored nation clauses legal
# query: amnesty definition
# processed 10 of 86
# query: how large is the canadian military
# query: foods that will help lower blood sugar
# query: cost to install a sump pump
# query: ferdinand digital release date
# query: how long it takes to get a debit memo at uop
# processed 15 of 86
# query: how long does blood take to replenish afet lossof blood
# query: how long is the typical bungee jump
# query: how long is recovery from a broken humerus
# query: causes of complex visual hallucinations
# query: chart of good and bad cholesterol
# processed 20 of 86
# query: how many calories a day are lost breastfeeding
# query: how much does a residential elevator cost
# query: how to measure a square meters
# query: is it safe for pregnant women to eat pepperoni
# query: is a little caffeine ok during pregnancy
# processed 25 of 86
# query: is overeating an eating disorder?
# query: is good cholesterol really good
# query: how to buy a mcdonald's franchise cost
# query: how many representatives does texas have
# query: minecraft 1.9.2 how to make fences
# processed 30 of 86
# query: name of origin for mercury
# query: what kind of fruit trees grow in Ky
# query: major climate characteristics of tropical rainforests
# query: cost of dexlansoprazole
# query: is pizza considered fast food
# processed 35 of 86
# query: types of fruit trees
# query: midway definition
# query: is the canadian open on tv
# query: number of us house of representatives
# query: what chemicals to use on canadian thistle
# processed 40 of 86
# query: synonyms for ancient
# query: sausage party release date
# query: what is algebra really about
# query: synonyms for density
# query: what are chemical symbols used for
# processed 45 of 86
# query: synonyms for eruption
# query: we happy few final release date
# query: what are good food sources for magnesium
# query: using commas correctly in sentences
# query: weight of wistar rat
# processed 50 of 86
# query: synonyms of impress
# query: what are some foods pregnant women avoid
# query: what are roof rats
# query: what did the non-cooperation movement call upon indians to do
# query: what causes dark spots around the stem of tomatoes
# processed 55 of 86
# query: what county is williamsport, pa located?
# query: what county is williamsport, pa
# query: what causes severe constipation after eating dark chocolate
# query: what are typical cna working hours
# query: what did rudolf virchow do for the cells
# processed 60 of 86
# query: what did textiles do in the industrial revolution
# query: what do the endoplasmic reticulum do
# query: what does indirect contempt of court mean
# query: what is in niacin
# query: what diseases do rats carry
# processed 65 of 86
# query: what is aluminum hydroxide gel
# query: what fruit is native to australia
# query: what information does a chemical equation contain
# query: what is causing my adrenal rushes and brain fog
# query: what drove the industrial revolution
# processed 70 of 86
# query: what is the waiting period for workers compensation benefits in ok?
# query: what is the release date for the wonder movie
# query: what is made of aluminum
# query: what is  the synonyms  of  hobby
# query: what is the recovery time for liposuction
# processed 75 of 86
# query: what is the genus of the weeping willow tree
# query: what is the average cost of a work related back injury
# query: who does jonathan stewart play for
# query: where is harrison city pa
# query: what month do computers go on sale
# processed 80 of 86
# query: what size can a carry on duffle bag be when flying
# query: which types of organisms are always located at the beginning of the food chain
# query: where does eggplant grow
# query: wow release date
# query: where were the scenes from hogwarts filmed
# processed 85 of 86
# query: who developed the esi triage system

# %%
rr_df
# Out:
#      qid  original  degree_2  degree_3  degree_4  degree_4_split  degree_8  \
# 0    0.0  0.125000  0.106061  0.138995  0.069765        0.119697  0.397500
# 1    1.0  0.083333  0.191850  0.168333  0.057706        0.100033  0.057555
# 2    2.0  0.500000  0.087302  0.097510  0.086710        0.072791  0.063782
# 3    3.0  0.071429  0.156136  0.107792  0.074496        0.191685  0.046238
# 4    4.0  0.050000  0.288383  0.142120  0.157023        0.096338  0.079176
# ..   ...       ...       ...       ...       ...             ...       ...
# 81  81.0  0.071429  0.209028  0.084828  0.061150        0.128382  0.038967
# 82  82.0  0.166667  0.162202  0.108333  0.294850        0.069179  0.094428
# 83  83.0  0.142857  0.106755  0.055571  0.064624        0.078687  0.038101
# 84  84.0  0.333333  0.347619  0.061651  0.207917        0.046234  0.118189
# 85  85.0  0.250000  0.073988  0.398148  0.079070        0.072475  0.060018
#
#     degree_8_split  original_irrelevant
# 0         0.069826             0.044553
# 1         0.078882             0.173504
# 2         0.157887             0.165609
# 3         0.066561             0.180717
# 4         0.077837             0.084411
# ..             ...                  ...
# 81        0.080688             0.200650
# 82        0.056634             0.097453
# 83        0.051005             0.295871
# 84        0.058250             0.049503
# 85        0.062684             0.106658
#
# [86 rows x 9 columns]

# %%
from datetime import datetime

def get_timestamp():
    now = datetime.now()
    return now.strftime("%Y-%m-%d_%H-%M")

# %%
EVAL_DIR = '/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/eval'

fn = 'rr_queries_model_sbert_' + get_timestamp() + '.csv'
rr_df.to_csv(os.path.join(EVAL_DIR, fn), index=None)
