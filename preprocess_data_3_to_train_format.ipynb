# %%
import os
import pandas as pd
import numpy as np
from enum import Enum
import itertools
import random
from sklearn.model_selection import train_test_split

# %%
import nltk
nltk.download('punkt', download_dir='/run/media/root/Windows/Users/agnes/tmp')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /run/media/root/Windows/Users/agnes/tmp...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# split train(+dev)/test:

# test is same format as here
# train(+dev) is: 

# 1
# - only "original" documents
# - split the 'doc' content, in sentences
# - all sentences from positive doc, will be labeled as positive
# - all sentences from negative doc, will be labeled as negative
# (optionally) duplicate positive examples so that there are enough

# 2 (for entire doc-encoding)
# - only "original" documents
# (optionally) duplicate positive examples so that there are enough

# output type can be as follows:
# normal:   qid, query, rel, doc
# triplet:  qid, query, doc_negative, doc_positive

# %%
class DocType(Enum):
    sentence = 0
    entire_doc = 1  

class LossType(Enum):
    regression = 0
    triplet = 1

# %%
def get_combis_sentences(qid, query_sentences, docs_sentences, rel_label):
    new_query_df = pd.DataFrame(columns=['qid', 'sent_1', 'rel', 'sent_2'])
    for k in itertools.product(query_sentences, docs_sentences):
        sent_1 = k[0]
        for sent_2 in k[1]:
            new_query_df = new_query_df.append({'qid': qid, 'sent_1': sent_1, 
                                               'sent_2': sent_2, 'rel': rel_label}, 
                                               ignore_index=True)
    return new_query_df


def get_combis_docs(qid, query, docs, rel_label):
    new_query_df = pd.DataFrame(columns=['qid', 'sent_1', 'rel', 'sent_2'])
    for doc in docs:
        new_query_df = new_query_df.append({'qid': qid, 'sent_1': query, 
                                            'sent_2': doc, 'rel': rel_label}, 
                                           ignore_index=True)    
    return new_query_df


def make_triplets(qid, query, positives, negatives, max_triplets=50):
    
    new_query_df = pd.DataFrame(columns=['qid', 'query', 'doc_positive', 'doc_negative'])
    
    combinations = list(itertools.product(positives, negatives))
    random.shuffle(combinations)
    for i, k in enumerate(combinations):
        new_query_df = new_query_df.append({'qid': qid, 'query': query, 
                                            'doc_positive': k[0], 
                                            'doc_negative': k[1]}, 
                                            ignore_index=True)    
        if i >= max_triplets:
            break
            
    return new_query_df


def make_train_data(queries_df, rel_label=1, adjust_sample_bias=True,
                    doc_type=DocType.sentence, limit=None, shuffle=False,
                    loss_type=LossType.regression,
                    sample_factor=1,
                    max_triplets_per_query=50):
    
    all_qids = list(sorted(set(queries_df['qid'])))
    
    queries_df = queries_df.loc[queries_df['type'] == 'original']
    
    if loss_type == LossType.regression:
        new_df = pd.DataFrame(columns=['qid', 'sent_1', 'rel', 'sent_2'])
    elif loss_type == LossType.triplet:
        new_df = pd.DataFrame(columns=['qid', 'query', 'doc_positive', 'doc_negative'])
    else:
        raise Exception('unknown LossType: ', loss_type)
        
    for i, qid in enumerate(all_qids):        
        qid_df = queries_df[queries_df['qid'] == qid].reset_index(drop=True)
        query = qid_df.iloc[0]["query"]
        
        docs_rels = qid_df['rel'].values
        rel_docs_mask = docs_rels == rel_label
        
        if doc_type == DocType.sentence:        
            query_sentences = nltk.tokenize.sent_tokenize(query)      
            docs_sentences = qid_df['doc'].apply(nltk.tokenize.sent_tokenize).values
            relevant_combis = get_combis_sentences(qid, query_sentences, 
                                                   docs_sentences[rel_docs_mask], rel_label)
            irrelevant_combis = get_combis_sentences(qid, query_sentences, 
                                                     docs_sentences[~rel_docs_mask], 0)            
        elif doc_type == DocType.entire_doc:
            relevant_combis = get_combis_docs(qid, query,  qid_df['doc'][rel_docs_mask], rel_label)
            irrelevant_combis = get_combis_docs(qid, query,  qid_df['doc'][~rel_docs_mask], 0)
        else:
            raise Exception('unknown DocType: ', doc_type)
        
        # ensure as many positive as negative labels
        if adjust_sample_bias:
            scale_factor = int(np.around(len(irrelevant_combis) / len(relevant_combis)))
            relevant_combis = pd.concat([relevant_combis] * scale_factor)
        
        data_to_add = [relevant_combis, irrelevant_combis]
        # make triplets
        if loss_type == LossType.triplet:
            data_to_add = make_triplets(qid, query, relevant_combis['sent_2'], 
                                                    irrelevant_combis['sent_2'],
                                                    max_triplets=max_triplets_per_query)
        
        if sample_factor < 1:
            data_to_add = data_to_add.sample(sample_factor)
        new_df = new_df.append(data_to_add)
        
        if limit is not None and (i+1) >= limit:
            break
        if (i+1) % 50 == 0:
            print('processed query {:d} of {:d}'.format(i+1, len(all_qids)))
            
    if shuffle:
        return new_df.sample(frac=1)
    return new_df

# %%
data_dir = '/run/media/root/Windows/Users/agnes/Downloads/data/msmarco'

fn = os.path.join(data_dir, 'queries3_od.csv')

df = pd.read_csv(fn)

df.head(3)
# Out:
#    qid                            query  rel      type  \
# 0    0  aaa a common cause of a skid is    0  original
# 1    0  aaa a common cause of a skid is    0  original
# 2    0  aaa a common cause of a skid is    0  original
#
#                                                  doc
# 0  6. When diamonds are what you want, only the f...
# 1  There are probably 50-80 grams of sugar in a c...
# 2  price ceiling: A legally determined maximum pr...

# %%
TRAIN_DATA_DIR = '/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/train_data'

# %%
ofn_prefix = os.path.splitext(os.path.basename(fn))[0]
ofn_prefix
# Out:
# 'queries3_od'

# %%
train_data_entiredoc_regression = make_train_data(df, doc_type=DocType.entire_doc, 
                                                  loss_type=LossType.regression)

train_data_entiredoc_regression.to_csv(os.path.join(TRAIN_DATA_DIR, 
                                                    f'{ofn_prefix}_entiredoc_regression.csv'),
                                                    index=None)
# Out:
# processed query 50 of 20117
# processed query 100 of 20117
# processed query 150 of 20117
# processed query 200 of 20117
# processed query 250 of 20117
# processed query 300 of 20117
# processed query 350 of 20117
# processed query 400 of 20117
# processed query 450 of 20117
# processed query 500 of 20117
# processed query 550 of 20117
# processed query 600 of 20117
# processed query 650 of 20117
# processed query 700 of 20117
# processed query 750 of 20117
# processed query 800 of 20117
# processed query 850 of 20117
# processed query 900 of 20117
# processed query 950 of 20117
# processed query 1000 of 20117
# processed query 1050 of 20117
# processed query 1100 of 20117
# processed query 1150 of 20117
# processed query 1200 of 20117
# processed query 1250 of 20117
# processed query 1300 of 20117
# processed query 1350 of 20117
# processed query 1400 of 20117
# processed query 1450 of 20117
# processed query 1500 of 20117
# processed query 1550 of 20117
# processed query 1600 of 20117
# processed query 1650 of 20117
# processed query 1700 of 20117
# processed query 1750 of 20117
# processed query 1800 of 20117
# processed query 1850 of 20117
# processed query 1900 of 20117
# processed query 1950 of 20117
# processed query 2000 of 20117
# processed query 2050 of 20117
# processed query 2100 of 20117
# processed query 2150 of 20117
# processed query 2200 of 20117
# processed query 2250 of 20117
# processed query 2300 of 20117
# processed query 2350 of 20117
# processed query 2400 of 20117
# processed query 2450 of 20117
# processed query 2500 of 20117
# processed query 2550 of 20117
# processed query 2600 of 20117
# processed query 2650 of 20117
# processed query 2700 of 20117
# processed query 2750 of 20117
# processed query 2800 of 20117
# processed query 2850 of 20117
# processed query 2900 of 20117
# processed query 2950 of 20117
# processed query 3000 of 20117
# processed query 3050 of 20117
# processed query 3100 of 20117
# processed query 3150 of 20117
# processed query 3200 of 20117
# processed query 3250 of 20117
# processed query 3300 of 20117
# processed query 3350 of 20117
# processed query 3400 of 20117
# processed query 3450 of 20117
# processed query 3500 of 20117
# processed query 3550 of 20117
# processed query 3600 of 20117
# processed query 3650 of 20117
# processed query 3700 of 20117
# processed query 3750 of 20117
# processed query 3800 of 20117
# processed query 3850 of 20117
# processed query 3900 of 20117
# processed query 3950 of 20117
# processed query 4000 of 20117
# processed query 4050 of 20117
# processed query 4100 of 20117
# processed query 4150 of 20117
# processed query 4200 of 20117
# processed query 4250 of 20117
# processed query 4300 of 20117
# processed query 4350 of 20117
# processed query 4400 of 20117
# processed query 4450 of 20117
# processed query 4500 of 20117
# processed query 4550 of 20117
# processed query 4600 of 20117
# processed query 4650 of 20117
# processed query 4700 of 20117
# processed query 4750 of 20117
# processed query 4800 of 20117
# processed query 4850 of 20117
# processed query 4900 of 20117
# processed query 4950 of 20117
# processed query 5000 of 20117
# processed query 5050 of 20117
# processed query 5100 of 20117
# processed query 5150 of 20117
# processed query 5200 of 20117
# processed query 5250 of 20117
# processed query 5300 of 20117
# processed query 5350 of 20117
# processed query 5400 of 20117
# processed query 5450 of 20117
# processed query 5500 of 20117
# processed query 5550 of 20117
# processed query 5600 of 20117
# processed query 5650 of 20117
# processed query 5700 of 20117
# processed query 5750 of 20117
# processed query 5800 of 20117
# processed query 5850 of 20117
# processed query 5900 of 20117
# processed query 5950 of 20117
# processed query 6000 of 20117
# processed query 6050 of 20117
# processed query 6100 of 20117
# processed query 6150 of 20117
# processed query 6200 of 20117
# processed query 6250 of 20117
# processed query 6300 of 20117
# processed query 6350 of 20117
# processed query 6400 of 20117
# processed query 6450 of 20117
# processed query 6500 of 20117
# processed query 6550 of 20117
# processed query 6600 of 20117
# processed query 6650 of 20117
# processed query 6700 of 20117
# processed query 6750 of 20117
# processed query 6800 of 20117
# processed query 6850 of 20117
# processed query 6900 of 20117
# processed query 6950 of 20117
# processed query 7000 of 20117
# processed query 7050 of 20117
# processed query 7100 of 20117
# processed query 7150 of 20117
# processed query 7200 of 20117
# processed query 7250 of 20117
# processed query 7300 of 20117
# processed query 7350 of 20117
# processed query 7400 of 20117
# processed query 7450 of 20117
# processed query 7500 of 20117
# processed query 7550 of 20117
# processed query 7600 of 20117
# processed query 7650 of 20117
# processed query 7700 of 20117
# processed query 7750 of 20117
# processed query 7800 of 20117
# processed query 7850 of 20117
# processed query 7900 of 20117
# processed query 7950 of 20117
# processed query 8000 of 20117
# processed query 8050 of 20117
# processed query 8100 of 20117
# processed query 8150 of 20117
# processed query 8200 of 20117
# processed query 8250 of 20117
# processed query 8300 of 20117
# processed query 8350 of 20117
# processed query 8400 of 20117
# processed query 8450 of 20117
# processed query 8500 of 20117
# processed query 8550 of 20117
# processed query 8600 of 20117
# processed query 8650 of 20117
# processed query 8700 of 20117
# processed query 8750 of 20117
# processed query 8800 of 20117
# processed query 8850 of 20117
# processed query 8900 of 20117
# processed query 8950 of 20117
# processed query 9000 of 20117
# processed query 9050 of 20117
# processed query 9100 of 20117
# processed query 9150 of 20117
# processed query 9200 of 20117
# processed query 9250 of 20117
# processed query 9300 of 20117
# processed query 9350 of 20117
# processed query 9400 of 20117
# processed query 9450 of 20117
# processed query 9500 of 20117
# processed query 9550 of 20117
# processed query 9600 of 20117
# processed query 9650 of 20117
# processed query 9700 of 20117
# processed query 9750 of 20117
# processed query 9800 of 20117
# processed query 9850 of 20117
# processed query 9900 of 20117
# processed query 9950 of 20117
# processed query 10000 of 20117
# processed query 10050 of 20117
# processed query 10100 of 20117
# processed query 10150 of 20117
# processed query 10200 of 20117
# processed query 10250 of 20117
# processed query 10300 of 20117
# processed query 10350 of 20117
# processed query 10400 of 20117
# processed query 10450 of 20117
# processed query 10500 of 20117
# processed query 10550 of 20117
# processed query 10600 of 20117
# processed query 10650 of 20117
# processed query 10700 of 20117
# processed query 10750 of 20117
# processed query 10800 of 20117
# processed query 10850 of 20117
# processed query 10900 of 20117
# processed query 10950 of 20117
# processed query 11000 of 20117
# processed query 11050 of 20117
# processed query 11100 of 20117
# processed query 11150 of 20117
# processed query 11200 of 20117
# processed query 11250 of 20117
# processed query 11300 of 20117
# processed query 11350 of 20117
# processed query 11400 of 20117
# processed query 11450 of 20117
# processed query 11500 of 20117
# processed query 11550 of 20117
# processed query 11600 of 20117
# processed query 11650 of 20117
# processed query 11700 of 20117
# processed query 11750 of 20117
# processed query 11800 of 20117
# processed query 11850 of 20117
# processed query 11900 of 20117
# processed query 11950 of 20117
# processed query 12000 of 20117
# processed query 12050 of 20117
# processed query 12100 of 20117
# processed query 12150 of 20117
# processed query 12200 of 20117
# processed query 12250 of 20117
# processed query 12300 of 20117
# processed query 12350 of 20117
# processed query 12400 of 20117
# processed query 12450 of 20117
# processed query 12500 of 20117
# processed query 12550 of 20117
# processed query 12600 of 20117
# processed query 12650 of 20117
# processed query 12700 of 20117
# processed query 12750 of 20117
# processed query 12800 of 20117
# processed query 12850 of 20117
# processed query 12900 of 20117
# processed query 12950 of 20117
# processed query 13000 of 20117
# processed query 13050 of 20117
# processed query 13100 of 20117
# processed query 13150 of 20117
# processed query 13200 of 20117
# processed query 13250 of 20117
# processed query 13300 of 20117
# processed query 13350 of 20117
# processed query 13400 of 20117
# processed query 13450 of 20117
# processed query 13500 of 20117
# processed query 13550 of 20117
# processed query 13600 of 20117
# processed query 13650 of 20117
# processed query 13700 of 20117
# processed query 13750 of 20117
# processed query 13800 of 20117
# processed query 13850 of 20117
# processed query 13900 of 20117
# processed query 13950 of 20117
# processed query 14000 of 20117
# processed query 14050 of 20117
# processed query 14100 of 20117
# processed query 14150 of 20117
# processed query 14200 of 20117
# processed query 14250 of 20117
# processed query 14300 of 20117
# processed query 14350 of 20117
# processed query 14400 of 20117
# processed query 14450 of 20117
# processed query 14500 of 20117
# processed query 14550 of 20117
# processed query 14600 of 20117
# processed query 14650 of 20117
# processed query 14700 of 20117
# processed query 14750 of 20117
# processed query 14800 of 20117
# processed query 14850 of 20117
# processed query 14900 of 20117
# processed query 14950 of 20117
# processed query 15000 of 20117
# processed query 15050 of 20117
# processed query 15100 of 20117
# processed query 15150 of 20117
# processed query 15200 of 20117
# processed query 15250 of 20117
# processed query 15300 of 20117
# processed query 15350 of 20117
# processed query 15400 of 20117
# processed query 15450 of 20117
# processed query 15500 of 20117
# processed query 15550 of 20117
# processed query 15600 of 20117
# processed query 15650 of 20117
# processed query 15700 of 20117
# processed query 15750 of 20117
# processed query 15800 of 20117
# processed query 15850 of 20117
# processed query 15900 of 20117
# processed query 15950 of 20117
# processed query 16000 of 20117
# processed query 16050 of 20117
# processed query 16100 of 20117
# processed query 16150 of 20117
# processed query 16200 of 20117
# processed query 16250 of 20117
# processed query 16300 of 20117
# processed query 16350 of 20117
# processed query 16400 of 20117
# processed query 16450 of 20117
# processed query 16500 of 20117
# processed query 16550 of 20117
# processed query 16600 of 20117
# processed query 16650 of 20117
# processed query 16700 of 20117
# processed query 16750 of 20117
# processed query 16800 of 20117
# processed query 16850 of 20117
# processed query 16900 of 20117
# processed query 16950 of 20117
# processed query 17000 of 20117
# processed query 17050 of 20117
# processed query 17100 of 20117
# processed query 17150 of 20117
# processed query 17200 of 20117
# processed query 17250 of 20117
# processed query 17300 of 20117
# processed query 17350 of 20117
# processed query 17400 of 20117
# processed query 17450 of 20117
# processed query 17500 of 20117
# processed query 17550 of 20117
# processed query 17600 of 20117
# processed query 17650 of 20117
# processed query 17700 of 20117
# processed query 17750 of 20117
# processed query 17800 of 20117
# processed query 17850 of 20117
# processed query 17900 of 20117
# processed query 17950 of 20117
# processed query 18000 of 20117
# processed query 18050 of 20117
# processed query 18100 of 20117
# processed query 18150 of 20117
# processed query 18200 of 20117
# processed query 18250 of 20117
# processed query 18300 of 20117
# processed query 18350 of 20117
# processed query 18400 of 20117
# processed query 18450 of 20117
# processed query 18500 of 20117
# processed query 18550 of 20117
# processed query 18600 of 20117
# processed query 18650 of 20117
# processed query 18700 of 20117
# processed query 18750 of 20117
# processed query 18800 of 20117
# processed query 18850 of 20117
# processed query 18900 of 20117
# processed query 18950 of 20117
# processed query 19000 of 20117
# processed query 19050 of 20117
# processed query 19100 of 20117
# processed query 19150 of 20117
# processed query 19200 of 20117
# processed query 19250 of 20117
# processed query 19300 of 20117
# processed query 19350 of 20117
# processed query 19400 of 20117
# processed query 19450 of 20117
# processed query 19500 of 20117
# processed query 19550 of 20117
# processed query 19600 of 20117
# processed query 19650 of 20117
# processed query 19700 of 20117
# processed query 19750 of 20117
# processed query 19800 of 20117
# processed query 19850 of 20117
# processed query 19900 of 20117
# processed query 19950 of 20117
# processed query 20000 of 20117
# processed query 20050 of 20117
# processed query 20100 of 20117

# %%
train_data_sentences_regression = make_train_data(df, doc_type=DocType.sentence, 
                                                  loss_type=LossType.regression)

train_data_sentences_regression.to_csv(os.path.join(TRAIN_DATA_DIR, 
                                                    f'{ofn_prefix}_sentences_regression.csv'),
                                                     index=None)
# Out:
# processed query 50 of 20117
# processed query 100 of 20117
# processed query 150 of 20117
# processed query 200 of 20117
# processed query 250 of 20117
# processed query 300 of 20117
# processed query 350 of 20117
# processed query 400 of 20117
# processed query 450 of 20117
# processed query 500 of 20117
# processed query 550 of 20117
# processed query 600 of 20117
# processed query 650 of 20117
# processed query 700 of 20117
# processed query 750 of 20117
# processed query 800 of 20117
# processed query 850 of 20117
# processed query 900 of 20117
# processed query 950 of 20117
# processed query 1000 of 20117
# processed query 1050 of 20117
# processed query 1100 of 20117
# processed query 1150 of 20117
# processed query 1200 of 20117
# processed query 1250 of 20117
# processed query 1300 of 20117
# processed query 1350 of 20117
# processed query 1400 of 20117
# processed query 1450 of 20117
# processed query 1500 of 20117
# processed query 1550 of 20117
# processed query 1600 of 20117
# processed query 1650 of 20117
# processed query 1700 of 20117
# processed query 1750 of 20117
# processed query 1800 of 20117
# processed query 1850 of 20117
# processed query 1900 of 20117
# processed query 1950 of 20117
# processed query 2000 of 20117
# processed query 2050 of 20117
# processed query 2100 of 20117
# processed query 2150 of 20117
# processed query 2200 of 20117
# processed query 2250 of 20117
# processed query 2300 of 20117
# processed query 2350 of 20117
# processed query 2400 of 20117
# processed query 2450 of 20117
# processed query 2500 of 20117
# processed query 2550 of 20117
# processed query 2600 of 20117
# processed query 2650 of 20117
# processed query 2700 of 20117
# processed query 2750 of 20117
# processed query 2800 of 20117
# processed query 2850 of 20117
# processed query 2900 of 20117
# processed query 2950 of 20117
# processed query 3000 of 20117
# processed query 3050 of 20117
# processed query 3100 of 20117
# processed query 3150 of 20117
# processed query 3200 of 20117
# processed query 3250 of 20117
# processed query 3300 of 20117
# processed query 3350 of 20117
# processed query 3400 of 20117
# processed query 3450 of 20117
# processed query 3500 of 20117
# processed query 3550 of 20117
# processed query 3600 of 20117
# processed query 3650 of 20117
# processed query 3700 of 20117
# processed query 3750 of 20117
# processed query 3800 of 20117
# processed query 3850 of 20117
# processed query 3900 of 20117
# processed query 3950 of 20117
# processed query 4000 of 20117
# processed query 4050 of 20117
# processed query 4100 of 20117
# processed query 4150 of 20117
# processed query 4200 of 20117
# processed query 4250 of 20117
# processed query 4300 of 20117
# processed query 4350 of 20117
# processed query 4400 of 20117
# processed query 4450 of 20117
# processed query 4500 of 20117
# processed query 4550 of 20117
# processed query 4600 of 20117
# processed query 4650 of 20117
# processed query 4700 of 20117
# processed query 4750 of 20117
# processed query 4800 of 20117
# processed query 4850 of 20117
# processed query 4900 of 20117
# processed query 4950 of 20117
# processed query 5000 of 20117
# processed query 5050 of 20117
# processed query 5100 of 20117
# processed query 5150 of 20117
# processed query 5200 of 20117
# processed query 5250 of 20117
# processed query 5300 of 20117
# processed query 5350 of 20117
# processed query 5400 of 20117
# processed query 5450 of 20117
# processed query 5500 of 20117
# processed query 5550 of 20117
# processed query 5600 of 20117
# processed query 5650 of 20117
# processed query 5700 of 20117
# processed query 5750 of 20117
# processed query 5800 of 20117
# processed query 5850 of 20117
# processed query 5900 of 20117
# processed query 5950 of 20117
# processed query 6000 of 20117
# processed query 6050 of 20117
# processed query 6100 of 20117
# processed query 6150 of 20117
# processed query 6200 of 20117
# processed query 6250 of 20117
# processed query 6300 of 20117
# processed query 6350 of 20117
# processed query 6400 of 20117
# processed query 6450 of 20117
# processed query 6500 of 20117
# processed query 6550 of 20117
# processed query 6600 of 20117
# processed query 6650 of 20117
# processed query 6700 of 20117
# processed query 6750 of 20117
# processed query 6800 of 20117
# processed query 6850 of 20117
# processed query 6900 of 20117
# processed query 6950 of 20117
# processed query 7000 of 20117
# processed query 7050 of 20117
# processed query 7100 of 20117
# processed query 7150 of 20117
# processed query 7200 of 20117
# processed query 7250 of 20117
# processed query 7300 of 20117
# processed query 7350 of 20117
# processed query 7400 of 20117
# processed query 7450 of 20117
# processed query 7500 of 20117
# processed query 7550 of 20117
# processed query 7600 of 20117
# processed query 7650 of 20117
# processed query 7700 of 20117
# processed query 7750 of 20117
# processed query 7800 of 20117
# processed query 7850 of 20117
# processed query 7900 of 20117
# processed query 7950 of 20117
# processed query 8000 of 20117
# processed query 8050 of 20117
# processed query 8100 of 20117
# processed query 8150 of 20117
# processed query 8200 of 20117
# processed query 8250 of 20117
# processed query 8300 of 20117
# processed query 8350 of 20117
# processed query 8400 of 20117
# processed query 8450 of 20117
# processed query 8500 of 20117
# processed query 8550 of 20117
# processed query 8600 of 20117
# processed query 8650 of 20117
# processed query 8700 of 20117
# processed query 8750 of 20117
# processed query 8800 of 20117
# processed query 8850 of 20117
# processed query 8900 of 20117
# processed query 8950 of 20117
# processed query 9000 of 20117
# processed query 9050 of 20117
# processed query 9100 of 20117
# processed query 9150 of 20117
# processed query 9200 of 20117
# processed query 9250 of 20117
# processed query 9300 of 20117
# processed query 9350 of 20117
# processed query 9400 of 20117
# processed query 9450 of 20117
# processed query 9500 of 20117
# processed query 9550 of 20117
# processed query 9600 of 20117
# processed query 9650 of 20117
# processed query 9700 of 20117
# processed query 9750 of 20117
# processed query 9800 of 20117
# processed query 9850 of 20117
# processed query 9900 of 20117
# processed query 9950 of 20117
# processed query 10000 of 20117
# processed query 10050 of 20117
# processed query 10100 of 20117
# processed query 10150 of 20117
# processed query 10200 of 20117
# processed query 10250 of 20117
# processed query 10300 of 20117
# processed query 10350 of 20117
# processed query 10400 of 20117
# processed query 10450 of 20117
# processed query 10500 of 20117
# processed query 10550 of 20117
# processed query 10600 of 20117
# processed query 10650 of 20117
# processed query 10700 of 20117
# processed query 10750 of 20117
# processed query 10800 of 20117
# processed query 10850 of 20117
# processed query 10900 of 20117
# processed query 10950 of 20117
# processed query 11000 of 20117
# processed query 11050 of 20117
# processed query 11100 of 20117
# processed query 11150 of 20117
# processed query 11200 of 20117
# processed query 11250 of 20117
# processed query 11300 of 20117
# processed query 11350 of 20117
# processed query 11400 of 20117
# processed query 11450 of 20117
# processed query 11500 of 20117
# processed query 11550 of 20117
# processed query 11600 of 20117
# processed query 11650 of 20117
# processed query 11700 of 20117
# processed query 11750 of 20117

# %%
train_data_entiredoc_triplet = make_train_data(df, doc_type=DocType.entire_doc, 
                                                   loss_type=LossType.triplet,
                                                   max_triplets_per_query=30)

train_data_entiredoc_triplet.to_csv(os.path.join(TRAIN_DATA_DIR, 
                                                 f'{ofn_prefix}_entiredoc_triplet.csv'), 
                                                 index=None)

# %%
train_data_sentences_triplet = make_train_data(df, doc_type=DocType.sentence, 
                                                   loss_type=LossType.triplet,
                                                   max_triplets_per_query=30)

train_data_sentences_triplet.to_csv(os.path.join(TRAIN_DATA_DIR, 
                                                 f'{ofn_prefix}_sentences_triplet.csv'), 
                                                 index=None)

# %%
# split data into train, dev and test sets
##########################################

all_qids = list(set(df['qid']))

qids_train, qids_test = train_test_split(all_qids, test_size=400, random_state=1234)

qids_train, qids_dev = train_test_split(qids_train, test_size=150, random_state=1234)

print('nr train: {:d}, nr. dev: {:d}, nr. test: {:d}'.format(
    len(qids_train), len(qids_dev), len(qids_test)))
# Out:
# nr train: 19567, nr. dev: 150, nr. test: 400

# %%
split_df = pd.DataFrame(columns=['qid', 'type'])
split_df['qid'] = qids_train + qids_dev + qids_test
split_df['type'] = ['train']*len(qids_train) + ['dev']*len(qids_dev) + ['test']*len(qids_test)

split_ofname = os.path.join(TRAIN_DATA_DIR, f'{ofn_prefix}_split.csv')

split_df.to_csv(split_ofname, index=None)

print('saved train/dev/test split to "{:s}"'.format(split_ofname))
# Out:
# saved train/dev/test split to "/run/media/root/Windows/Users/agnes/Downloads/data/msmarco/train_data/queries3_od_split.csv"

# %%
31*1000
# Out:
# 31000

# %%
31000 / 488047 * 100
# Out:
# 6.351847260612195
